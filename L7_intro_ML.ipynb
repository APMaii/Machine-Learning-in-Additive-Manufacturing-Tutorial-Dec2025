# %% [markdown]
# ## Machine Learning
#
# - Artificial intelligence
# - Aim : Machine (0,1 sade, advanced calculator , inteelligent , ) -> shabihe ensan bebine, yad begire , tasmim begire (amal kone)
#
#
#
# - First geenration --> AI nasle yek
# - Automation --> IF else
#
# - while ta abad anajm bde , if threshold < 20 : stop
#
# - Chatbot -> if else -->

# %%
answer1 = input('salam khoobi?:')

khobam_list = ['khobam', 'khoobam', 'mersi', 'mamnoon']
if answer1.lower().split() in khobam_list :
    print('chekahabr?')

# %% [markdown]
# - Robota aksaran nasle yek bodan --> beehhshon ssensor bod b kamareshon ag mikhordan zamin
# - sensore misanjid pascal feshar vared mishe --> threshodl miresid
#
# Arm 2,3 boland mikard --> intelligent --> IF else too dar , automation
# nasle 1 -->100 salam footbal bazi konan hardafe bokhorn zmain ag oon feshari b kaamr felan adad bashe bolan mishe pishrafti
#
# --> Fekr shod --> man mikham robotam na tanha inaro anjam bde ,--> yad begire
# - Yad begrie --> 10 ta abzi --> in robotaye ma ghavi tar mishan --> hey bsihtar yad mign , upgrade

# %% [markdown]
# ## Second generation AI
# - Machine learning (Yadgirie machine hast --> 70-80% AI)
#
# AI ---> [rule-based models , optimization , Machine learning]

# %% [markdown]
# - Machine learning --> Yadgirie machine --> Machine mesle ensan bebine, yad begire amal kone

# %% [markdown]
# Machine elarnin koli shakh dare --> shakheye advanced --> DEEP LEARNING --> 100 000 , 1 million data , GPT , ... --> deep learning --> Dg saro kar darna ba 7 T word , ....

# %% [markdown]
# -- Zarrorie k ghabl az ML --> rajebe Rgeression Yechizaee bedonim dore konim

# %%
'''
dastgah dari --> temp 
---> takhalkhol ijad msihe dakheel mabvade man , --> density man 


rabete ee beyen in temp bva density dar nature (tabiat , donayeyy vagehi vojod )
hichki nmdione chie --> khoda midone


temp --> mire tasir mizare mcirostructrue --> melt pool , molecules , quantum in melting , dynamic --> solidifcation ,...
--> takhalkhol --> hezaran mechanism , hezaran type --> kole ina --> statistical mechanism --> entropy growth -->
density taghir mikone

temp -------> Density vojod dare

temp --> khodam taghir midam --> X  --> independent variable (moteghayere mostaghel)
density --.chziie k man moshahede mikonam --> Y dependent variable (moteghayere vabaste --> )
temp bar asase compelx pattrn tasir mizare rooye density
density = f (temp ) hast

damahaye motefavet --> density haye motefaveto daram


too ch dama , ch density ee bdast mairam?
1- ma nemitonim begim k too felan dama, density chand mishe
2- aya vaghean rabetee ee beyne density va temp vojod dare? [farze --> in rabete vojod dare]

#mano shoam nmidonim --> khoda midoni




#nature
density = f (temp)
density = a * temp + b

#
density = -0.012 * temp + 5





#Ma rafitm too azmayeshgah 10 ta noghte. 

#too damahaye motefavet , density hayemotegavet grftim


#donabel chi eem? --> donabel inim k rabeteye beyne y va x ro betonim dar bairim
#b ch dard mikhore?


#density = a * temp + b

#ma donable inim k paametr haye a va b ro b dast bairim

density = felan * temp + felan


#bejaye inek man baraye temp haey jadid brm azmayeshgah

#temp --> formole bala ---> density

#rabete ro fahmide

#---> Regression






'''
# Out:
# '\ndastgah dari --> temp \n---> takhalkhol ijad msihe dakheel mabvade man , --> density man \n\n\nrabete ee beyen in temp bva density dar nature (tabiat , donayeyy vagehi vojod )\nhichki nmdione chie --> khoda midone\n\n\ntemp --> mire tasir mizare mcirostructrue --> melt pool , molecules , quantum in melting , dynamic --> solidifcation ,...\n--> takhalkhol --> hezaran mechanism , hezaran type --> kole ina --> statistical mechanism --> entropy growth -->\ndensity taghir mikone\n\ntemp -------> Density vojod dare\n\ntemp --> khodam taghir midam --> X  --> independent variable (moteghayere mostaghel)\ndensity --.chziie k man moshahede mikonam --> Y dependent variable (moteghayere vabaste --> )\ntemp bar asase compelx pattrn tasir mizare rooye density\ndensity = f (temp ) hast\n\ndamahaye motefavet --> density haye motefaveto daram\n\n\ntoo ch dama , ch density ee bdast mairam?\n1- ma nemitonim begim k too felan dama, density chand mishe\n2- aya vaghean rabetee ee beyne density va temp 
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.95, 0.92, 0.89, 0.85, 0.80, 0.76, 0.71, 0.65, 0.60, 0.55])


plt.scatter(temp, density)
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.55, 0.60, 0.65, 0.71, 0.76, 0.80, 0.85, 0.89, 0.92, 0.95])


plt.scatter(temp, density)
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %%
#man midonam y = a * x + b hast
#bai bahm randomely --> a , b roshoro konim



import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.55, 0.60, 0.65, 0.71, 0.76, 0.80, 0.85, 0.89, 0.92, 0.95])

#ba a = 0.005 , b = 1

x = np.arange(100,1001,100)
a= 0.005
b= 1.0
#y = -0.0005 * x + 1.0
y = a * x + b


plt.scatter(temp, density)
plt.plot(x,y, color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %%
#a o b ro hads zadam --> a va b ro behtar entekhab konm k chi bshe --> in khat nazdik tar bshe roye dataee k daram

import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.55, 0.60, 0.65, 0.71, 0.76, 0.80, 0.85, 0.89, 0.92, 0.95])


x = np.arange(100,1001,100)
a= 0.005
b= 0.001
y = a * x + b


plt.scatter(temp, density)
plt.plot(x,y, color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.55, 0.60, 0.65, 0.71, 0.76, 0.80, 0.85, 0.89, 0.92, 0.95])


x = np.arange(100,1001,100)
a= 0.0005
b= 0.001
y = a * x + b


plt.scatter(temp, density)
plt.plot(x,y, color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.55, 0.60, 0.65, 0.71, 0.76, 0.80, 0.85, 0.89, 0.92, 0.95])


x = np.arange(100,1001,100)
a= 0.0005
b= 0.3
y = a * x + b


plt.scatter(temp, density)
plt.plot(x,y, color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.55, 0.60, 0.65, 0.71, 0.76, 0.80, 0.85, 0.89, 0.92, 0.95])


x = np.arange(100,1001,100)
a= 0.0005
b= 0.5
y = a * x + b


plt.scatter(temp, density)
plt.plot(x,y, color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
temp = np.array([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000])
density = np.array([0.55, 0.60, 0.65, 0.71, 0.76, 0.80, 0.85, 0.89, 0.92, 0.95])


x = np.arange(100,1001,100)
a= 0.00049
b= 0.5
y = a * x + b


plt.scatter(temp, density)
plt.plot(x,y, color='red')
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Density vs Temperature')
plt.grid(True)
plt.show()

# %% [markdown]
# ## mitonam begam in khate man represent mikone hamoon rabete ee k too nature bod , va fght khdoa midonest
# density = a * temp + b
# pas man migm agah ychzii peyda krdm k a o b hamon nis vali shabihesh (mdoeling)
#
# a= 0.00049
# b= 0.5
# y = a * x + b
#
#
# density = 0.00048 * temp + 0.5

# %%
#too har range a az dama --> density to peyda konm

new_temp = 735

a = 0.00048
b = 0.5
#density = 0.00048 * temp + 0.5
predicted_density = a * new_temp + b
print(f'Predicted density at {new_temp}°C is {predicted_density}')
# Out:
# Predicted density at 735°C is 0.8528

# %%
temp_range = np.linspace(0 , 2000 , 10)
a= 0.00048
b= 0.5
density_range = a* temp_range + b

plt.plot(temp_range, density_range, color='green')
plt.xlabel('Temperature (°C)')
plt.ylabel('Density')
plt.title('Predicted Density vs Temperature')
plt.grid(True)
plt.show()

# %% [markdown]
# ## chikar karidm mane ensan ?
#
#
# - 1- yekseri data dashtam --> X [1,2,3,..] --> Prcoess parameter (dastemone mitonim taghir bdim)
# y --> Target (khoroji ) --> Quality parameter --> mibinimesh, baramon kh moheme
#
# - 2- midonim yek rabete ee beyen y va x hast --> y = a*x + b
#
# - 3- done done a , b ro random ye guess mizanim
#
# - 4- misanjim khate chegahdr ba in noghat nazdike
#
# - 5- hey nazdik taresh mikonim mikonim --> (a,b) ta beresim b jaee k in dota shabihe bian roham
#
# - 6 -OOn a , b ma oon chzii has k too nature bode --> man rabete ro peyuda krdm y = a^ x + b^ be goonee  a^ ~ a b^ ~b
#
# - 7 - new x --> predict = a^ * new_x + b^
